# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn import *

# %%
import pandas as pd

test = pd.read_csv('test.csv', delimiter = ',')
train = pd.read_csv('train.csv', delimiter = ',')
submission = pd.read_csv('gender_submission.csv',delimiter = ',')

# %%
def sexonehot(df):
    a =df['Sex'].copy()
    b=[]
    for i in range(len(a)):
        if a[i] == 'male':
            b.append(0)
        else:
            b.append(1)
    df['Sex_encode'] = pd.DataFrame(b)

# %%
sexonehot(train)

# %%
sexonehot(test)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Sex_encode     891 non-null int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
def embarkedonehot(df):
    l = []
    s = [1,0,0]
    q = [0,1,0]
    c = [0,0,1]
    n = [0,0,0]
    for i in range(len(df)):
        if df.Embarked[i] == 'S':
            l.append(s)
        elif df.Embarked[i] == 'Q':
            l.append(q)
        elif df.Embarked[i] == 'C':
            l.append(c)
        else:
            l.append(n)
    b = pd.DataFrame(l, columns=['embarked_S','embarked_Q','embarked_C'])
    df = df.join(b)

# %%
embarkedonehot(train)

# %%
def agemissingdata(df):
    df['Age'] = df['Age'].fillna(30)

# %%
def cabinloc(df):
    l1=[]
    l2=[]
    for i in range(len(df.Cabin)):
        if type(df.Cabin[i]) == str:
            l1.append(df.Cabin[i][0])
            l2.append(df.Cabin[i][1:])
        elif type(df.Cabin[i]) == int:
            l1.append(0)
            l2.append(0)
    df['cabinloc'] = pd.DataFrame(l1)

# %%
cabinloc(train)

# %%
len(train.cabinloc)
# Out:
# 891

# %%
def cabinonehot(df):
#선실 구역과 생존자 수의 관계
    c=[]
    b=[]
    d=[]
    e=[]
    a=[]
    f=[]
    g=[]
    t=[]

    for i in range(len(df)):
        if df.cabinloc[i] == 'C' and df.Survived[i] == 1:
            c.append(1)
        else :
            c.append(0)
        if df.cabinloc[i] == 'B' and df.Survived[i] == 1: 
            b.append(1)
        else:
            b.append(0)    
        if df.cabinloc[i] == 'D'and df.Survived[i] == 1: 
            d.append(1)
        else:
            d.append(0)        
        if df.cabinloc[i] == 'E' and df.Survived[i] == 1:
            e.append(1)
        else:
            e.append(0)
        if df.cabinloc[i] == 'A' and df.Survived[i] == 1:
            a.append(1)
        else:
            a.append(0)
        if df.cabinloc[i] == 'F'and df.Survived[i] == 1:
            f.append(1)
        else:
            f.append(0)
        if df.cabinloc[i] == 'G'and df.Survived[i] == 1:
            g.append(1)
        else:
            g.append(0)
        if df.cabinloc[i] == 'T'and df.Survived[i] == 1:
            t.append(1)
        else:
            t.append(0)
     
    df['cabinC'] = c
    df['cabinD'] = d
    df['cabinE'] = e
    df['cabinB'] = b
    df['cabinA'] = a
    df['cabinG'] = g
    df['cabinT'] = t
    df['cabinF'] = f

# %%
#훈련 시키기.
# 테스트, 훈련 셋 나누기

from sklearn.model_selection import train_test_split


X = train.loc[:,['Pclass','Fare','Sex_encode','Age',
            'SibSp', 'Parch', 'embarked_S', 'embarked_Q',
            'embarked_C', 'cabinC','cabinB','cabinE','cabinD',
            'cabinA','cabinF','cabinG','cabinT']]
y = train['Survived']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state = 0)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
# Pclass        891 non-null int64
# Fare          891 non-null float64
# Sex_encode    891 non-null int64
# Age           714 non-null float64
# SibSp         891 non-null int64
# Parch         891 non-null int64
# embarked_S    0 non-null float64
# embarked_Q    0 non-null float64
# embarked_C    0 non-null float64
# cabinC        891 non-null int64
# cabinB        891 non-null int64
# cabinE        891 non-null int64
# cabinD        891 non-null int64
# cabinA        891 non-null int64
# cabinF        891 non-null int64
# cabinG        891 non-null int64
# cabinT        891 non-null int64
# dtypes: float64(5), int64(12)
# memory usage: 118.4 KB

# %%
from sklearn.preprocessing import Normalizer
norm = Normalizer().fit(X)
norm_X = norm.transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-e168050d0ba2> in <module>
#       1 from sklearn.preprocessing import Normalizer
# ----> 2 norm = Normalizer().fit(X)
#       3 norm_X = norm.transform(X)
#
# c:\users\ajy\appdata\local\programs\python\python36\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#    1681         X : array-like
#    1682         """
# -> 1683         X = check_array(X, accept_sparse='csr')
#    1684         return self
#    1685
#
# c:\users\ajy\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# ...

# %%
norm_X_train, norm_X_test, y_train, y_test = train_test_split(norm_X, y, random_state = 0 )

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth = 4)
tree.fit(X_train, y_train)
display(
tree.score(X_train, y_train), tree.score(X_test, y_test) 
)
# Out:
# 0.844311377245509
# 0.820627802690583

# %%
tree

# %%
from sklearn.ensemble import RandomForestClassifier
rtree = RandomForestClassifier(max_depth = 6,min_samples_leaf=2, min_samples_split=6,
                              n_estimators=20)
rtree.fit(X_train,y_train)
display(
rtree.score(X_train, y_train), rtree.score(X_test, y_test) 
)
# Out:
# c:\users\ajy\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 0.8532934131736527
# 0.8385650224215246

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(C=10)
svc.fit(X_train,y_train)
display(
svc.score(X_train, y_train), svc.score(X_test, y_test) 
)
# Out:
# c:\users\ajy\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\ajy\appdata\local\programs\python\python36\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 0.8008982035928144
# 0.7802690582959642

# %%
train2 = train.copy()
train2.to_csv('train2',index=False)

# %%
pd.read_csv('train2',delimiter = ',')

# %%
train2.info()

# %%
pc = pd.get_dummies(train2.Pclass)

# %%
pc.columns = ['p1','p2','p3']
trian2=pd.concat([train2,pc], sort=False)

# %%
Fare = train2.Fare.copy()
Fare = Fare.astype(int)
pd.get_dummies(Fare)
Fare.min(),Fare.max()
Fare.describe()
plt.hist(Fare, bins = np.arange(0,500, 10))
Fare.describe()

# %%
from sklearn import preprocessing
normfare = preprocessing.normalize([Fare])

# Create range for your new columns
fare_range = zip(range(0,520), range(10,530))
new_df = pd.DataFrame()
# Iterate and create new columns, with the 0 and 1 encoding
for r in fare_range:
    new_df["fare_%d_to_%d" % r] = Fare.apply(lambda x: 1 if r[0]<= x <r[1]  else 0,axis=1)
new_df.head()

# %%
Fare.apply

# %%
for r in fare_range:
    print(r[0])

# %%
a = list(zip(range(0, 520), range(10, 530)))
np.arange(a[0][0],a[0][1])
Fare[0]

# %%
a,n= np.histogram(Fare,bins = np.arange(0,Fare.max()+10,10))
a,n

# %%
Fare.d

# %%
len(n)

# %%
#pd.get_dummies(Fare,dummy_na = True).info()
np.sort(Fare.unique())

# %%
labels = ['{0} - {1}'.format(i, i+9) for i in range(0,520,10)]
fare2=Fare.copy()
fare2 =pd.DataFrame({'fare': fare2})
labels

# %%
submission = pd.read_csv('gender_submission.csv')

# %%
test
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
prediction = rtree.predict(test)
submission['Survived'] = prediction
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-1a190a845525> in <module>
# ----> 1 prediction = rtree.predict(test)
#       2 submission['Survived'] = prediction
#
# c:\users\ajy\appdata\local\programs\python\python36\lib\site-packages\sklearn\ensemble\forest.py in predict(self, X)
#     541             The predicted classes.
#     542         """
# --> 543         proba = self.predict_proba(X)
#     544
#     545         if self.n_outputs_ == 1:
#
# c:\users\ajy\appdata\local\programs\python\python36\lib\site-packages\sklearn\ensemble\forest.py in predict_proba(self, X)
#     581         check_is_fitted(self, 'estimators_')
#     582         # Check data
# --> 583         X = self._validate_X_predict(X)
#     584
#     585         # Assign chunk of trees to jobs
#
# ...

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
rtree.fit(norm_X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f66d78174019> in <module>
# ----> 1 rtree.fit(norm_X_test)
#
# TypeError: fit() missing 1 required positional argument: 'y'
